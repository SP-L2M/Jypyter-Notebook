# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15, 5

# %%
df = pd.read_csv("sbi-data.csv")

# %%
ts_diff = np.diff(df["Time"])

# %%
# %matplotlib notebook
plt.plot(ts_diff)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="957">
